# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import random

# %%
iris = load_iris()

# %%
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.DataFrame(iris.target, columns=['y'])

# %%
df = pd.DataFrame(X)
df['y'] = y

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  y
# 0                5.1               3.5                1.4               0.2  0
# 1                4.9               3.0                1.4               0.2  0
# 2                4.7               3.2                1.3               0.2  0
# 3                4.6               3.1                1.5               0.2  0
# 4                5.0               3.6                1.4               0.2  0

# %%
class Perceptron:
    def __init__(self, df):
        x, y = df.loc[:, df.columns!='y'], df['y']
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)
        self.x_train = x_train
        self.x_train.insert(0,'x0',1)
        self.x_test = x_test
        self.x_test.insert(0,'x0',1)
        self.y_train = y_train
        self.y_test = y_test
        self.d_features = len(x.columns)
        self.n_datapoints = df.shape[0]
        self.l_classes = len(set(y))
        self.Ws = [np.array([0 for _ in range(self.d_features+1)]) for _ in range(self.l_classes)]

    def display_attr(self):
        print(self.Ws)

    def build_model(self):
        n = self.n_datapoints
        d = self.d_features
        l = self.l_classes

        Wolds = self.Ws
        Wnews = self.Ws
        epochs = 0
        eta = random.choice(np.linspace(0, 0.1, 1000))

        x = self.x_train
        y = self.y_train

        while True:
            if epochs!=0:
                for i, elt in enumerate(Wolds):
                    Wnews[i] = elt

            for i in range(n):
                x_vec = x.iloc[i]
                y_class = y.iloc[i]
                y_true = 0
                
                for j in range(l):
                    y_true = 1 if y_class==j else 0
                    Wolds[j] = Wolds[j]-eta*(sfmaxval-y_true)*x_vec
            
            brkflg = True
            epochs += 1
            
            for i, elt in enumerate(Wolds):
                if np.allclose(Wold[i],Wnew[i]):
                    brkflg = False

            if brkflg:
                break

# %%
x, y = df.loc[:, df.columns!='y'], df['y']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
x_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 36                 5.5               3.5                1.3               0.2
# 119                6.0               2.2                5.0               1.5
# 86                 6.7               3.1                4.7               1.5
# 89                 5.5               2.5                4.0               1.3
# 53                 5.5               2.3                4.0               1.3
# ..                 ...               ...                ...               ...
# 143                6.8               3.2                5.9               2.3
# 81                 5.5               2.4                3.7               1.0
# 131                7.9               3.8                6.4               2.0
# 29                 4.7               3.2                1.6               0.2
# 144                6.7               3.3                5.7               2.5
#
# [100 rows x 4 columns]

# %%
p1 = Perceptron(df)

# %%
p1.display_attr()
# Out:
# [array([0, 0, 0, 0, 0]), array([0, 0, 0, 0, 0]), array([0, 0, 0, 0, 0])]
