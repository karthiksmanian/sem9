# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
f = np.array([1, 2, 3])
h = np.array([1, -1])
y = signal.convolve(h, f)

# %%
plt.scatter([0, 1, 2], f)
plt.scatter([0, 1], h)
plt.scatter([0, 1, 2, 4], y)

# %%
t = np.linspace(0, 1, 100)
x = signal.square(2*np.pi*5*t)

# %%
y = np.convolve(x, h, 'same')

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
t=np.linspace(0,1,100)
x=signal.square(2*np.pi*5*t)
h=np.array([1,-1])
y=signal.convolve(x,h,'same')
plt.subplot(2,1,1),plt.plot(t,x)
plt.title('Input signal')
plt.subplot(2,1,2),plt.plot(t,y)
plt.title('Output signal')
plt.tight_layout()

# %%
h=np.ones(10)*(1/10) # Low pass filter
y=signal.convolve(x,h,'same')
plt.subplot(2,1,1),plt.plot(t,x)
plt.title('Input signal')
plt.subplot(2,1,2),plt.plot(t,y)
plt.title('Output signal')
plt.tight_layout()

# %%
h=np.ones(10)*(1/10)
w,H=signal.freqz(h,1) #Convert to freq.domain
plt.plot(w,np.abs(H)) #Plot the absolute value

# %%
h=np.array([1,-1])
w,H=signal.freqz(h,1) #Convert to freq.domain
plt.plot(w,np.abs(H)) #Plot the absolute value

# %%
# 2D convolution

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\temp.winserver\appdata\roaming\python\python310\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.0 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.23.5)

# %%
import cv2

# %%
x=cv2.imread('cameraman.tif',0)
h=np.array([[0,0,0],[0,1,0],[0,0,0]])
y=cv2.filter2D(x,-1,h)
plt.subplot(1,2,1),plt.imshow(x,cmap='gray')
plt.subplot(1,2,2),plt.imshow(y,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 3
#       1 x=cv2.imread('cameraman.tif',0)
#       2 h=np.array([[0,0,0],[0,1,0],[0,0,0]])
# ----> 3 y=cv2.filter2D(x,-1,h)
#       4 plt.subplot(1,2,1),plt.imshow(x,cmap='gray')
#       5 plt.subplot(1,2,2),plt.imshow(y,cmap='gray')
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\filter.dispatch.cpp:1528: error: (-215:Assertion failed) !_src.empty() in function 'cv::filter2D'
